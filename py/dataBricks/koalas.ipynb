# %%
# data
from sklearn import datasets
iris = datasets.load_iris()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### データの読み込み

# %% [markdown]
# ### 🐼

# %%
import pandas as pd

# %%
pd_df = pd.DataFrame(iris.data, columns=iris.feature_names)
display(pd_df.head())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sepal length (cm)</th><th>sepal width (cm)</th><th>petal length (cm)</th><th>petal width (cm)</th></tr></thead><tbody><tr><td>5.1</td><td>3.5</td><td>1.4</td><td>0.2</td></tr><tr><td>4.9</td><td>3.0</td><td>1.4</td><td>0.2</td></tr><tr><td>4.7</td><td>3.2</td><td>1.3</td><td>0.2</td></tr><tr><td>4.6</td><td>3.1</td><td>1.5</td><td>0.2</td></tr><tr><td>5.0</td><td>3.6</td><td>1.4</td><td>0.2</td></tr></tbody></table></div>

# %%
pd_pre = pd_df.add_prefix('panda_')
display(pd_pre.head())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>panda_sepal length (cm)</th><th>panda_sepal width (cm)</th><th>panda_petal length (cm)</th><th>panda_petal width (cm)</th></tr></thead><tbody><tr><td>5.1</td><td>3.5</td><td>1.4</td><td>0.2</td></tr><tr><td>4.9</td><td>3.0</td><td>1.4</td><td>0.2</td></tr><tr><td>4.7</td><td>3.2</td><td>1.3</td><td>0.2</td></tr><tr><td>4.6</td><td>3.1</td><td>1.5</td><td>0.2</td></tr><tr><td>5.0</td><td>3.6</td><td>1.4</td><td>0.2</td></tr></tbody></table></div>

# %%
pd_sort = pd_df.sort_values('sepal length (cm)', ascending=False)
display(pd_sort)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ### 🐨

# %%
dbutils.library.installPyPI("Koalas","0.8.0")
dbutils.library.restartPython()

# %%
import databricks.koalas as kl

# %%
# コアラ
kl_df = kl.DataFrame(iris.data, columns=iris.feature_names)
kl_df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">14</span><span class="ansired">]: </span>
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# </div>

# %%
kl_pre = kl_df.add_prefix('koala_')
kl_pre.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">16</span><span class="ansired">]: </span>
#    koala_sepal length (cm)  ...  koala_petal width (cm)
# 0                      5.1  ...                     0.2
# 1                      4.9  ...                     0.2
# 2                      4.7  ...                     0.2
# 3                      4.6  ...                     0.2
# 4                      5.0  ...                     0.2
#
# [5 rows x 4 columns]
# </div>

# %%
kl_sort = kl_df.sort_values('sepal length (cm)', ascending=False)
kl_sort
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">17</span><span class="ansired">]: </span>
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 131                7.9               3.8                6.4               2.0
# 117                7.7               3.8                6.7               2.2
# 122                7.7               2.8                6.7               2.0
# 118                7.7               2.6                6.9               2.3
# 135                7.7               3.0                6.1               2.3
# ...

# %%
prices = [350, 400, 500]
tdl_snacks = kl.Series(prices, index = ['churos', 'popcorn', 'porkRiceRoll'])
tdl_snacks.loc[['churos', 'popcorn']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">21</span><span class="ansired">]: </span>
# churos     350
# popcorn    400
# Name: 0, dtype: int64
# </div>

# %% [markdown]
# ### 🐍⚡

# %%
from pyspark.sql import SQLContext

# %%
# spark dataframe(ちょっとずるした)
sp_df = sqlContext.createDataFrame(pd_df)
sp_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+----------------+-----------------+----------------+
# sepal length (cm)|sepal width (cm)|petal length (cm)|petal width (cm)|
# +-----------------+----------------+-----------------+----------------+
#               5.1|             3.5|              1.4|             0.2|
#               4.9|             3.0|              1.4|             0.2|
#               4.7|             3.2|              1.3|             0.2|
#               4.6|             3.1|              1.5|             0.2|
#               5.0|             3.6|              1.4|             0.2|
# ...

# %%
sp_rename = sp_df.toDF('sp_sepal length (cm)', 'sp_sepal width (cm)', 'sp_petal length (cm)', 'sp_petal width (cm)')
sp_rename.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-------------------+--------------------+-------------------+
# sp_sepal length (cm)|sp_sepal width (cm)|sp_petal length (cm)|sp_petal width (cm)|
# +--------------------+-------------------+--------------------+-------------------+
#                  5.1|                3.5|                 1.4|                0.2|
#                  4.9|                3.0|                 1.4|                0.2|
#                  4.7|                3.2|                 1.3|                0.2|
#                  4.6|                3.1|                 1.5|                0.2|
# ...

# %%
sp_sort = sp_df.sort('sepal length (cm)', ascending=False).collect()
sp_sort
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">32</span><span class="ansired">]: </span>
# [Row(sepal length (cm)=7.9, sepal width (cm)=3.8, petal length (cm)=6.4, petal width (cm)=2.0),
#  Row(sepal length (cm)=7.7, sepal width (cm)=3.8, petal length (cm)=6.7, petal width (cm)=2.2),
#  Row(sepal length (cm)=7.7, sepal width (cm)=2.6, petal length (cm)=6.9, petal width (cm)=2.3),
#  Row(sepal length (cm)=7.7, sepal width (cm)=2.8, petal length (cm)=6.7, petal width (cm)=2.0),
#  Row(sepal length (cm)=7.7, sepal width (cm)=3.0, petal length (cm)=6.1, petal width (cm)=2.3),
# ...
